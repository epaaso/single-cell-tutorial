# %% [markdown]
# # Download GSE's

# %% [markdown]
# ## Libraries

# %%
import warnings

import urllib.request
import time
import re
from multiprocessing import cpu_count
from multiprocessing.pool import ThreadPool

import pandas as pd
import matplotlib.pyplot as plt
import numpy

import GEOparse

# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# ## Functions

# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), '..', 'download_scripts'))
from functions import download_parallel, get_geo_exprs

# %%
download_parallel([('https://ftp.ncbi.nlm.nih.gov/geo/series/GSE136nnn/GSE136831/suppl/GSE136831%5FRawCounts%5FSparse%2Emtx%2Egz', '/root/datos/maestria/netopaas/lung_scRNA/GSE136831/sparse.mtx.gz'),
                  ('https://ftp.ncbi.nlm.nih.gov/geo/series/GSE136nnn/GSE136831/suppl/GSE136831%5FAllCells%2EcellBarcodes%2Etxt%2Egz','barcodes.txt.gz'),
                  ('https://ftp.ncbi.nlm.nih.gov/geo/series/GSE136nnn/GSE136831/suppl/GSE136831%5FAllCells%2EGeneIDs%2Etxt%2Egz','ids.txt.gz')])
# Out:
# CPUS:  26
# url: https://ftp.ncbi.nlm.nih.gov/geo/series/GSE136nnn/GSE136831/suppl/GSE136831%5FAllCells%2EGeneIDs%2Etxt%2Egz time (s): 1.1830008029937744
# url: https://ftp.ncbi.nlm.nih.gov/geo/series/GSE136nnn/GSE136831/suppl/GSE136831%5FAllCells%2EcellBarcodes%2Etxt%2Egz time (s): 1.3969216346740723
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /opt/python/lib/python3.8/multiprocessing/pool.py in next(self, timeout)
#     850             try:
# --> 851                 item = self._items.popleft()
#     852             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2734/3328819473.py in <module>
# ----> 1 download_parallel([('https://ftp.ncbi.nlm.nih.gov/geo/series/GSE136nnn/GSE136831/suppl/GSE136831%5FRawCounts%5FSparse%2Emtx%2Egz', '/root/datos/maestria/netopaas/lung_scRNA/GSE136831/sparse.mtx.gz'),
#       2                   ('https://ftp.ncbi.nlm.nih.gov/geo/series/GSE136nnn/GSE136831/suppl/GSE136831%5FAllCells%2EcellBarcodes%2Etxt%2Egz','barcodes.txt.gz'),
#       3                   ('https://ftp.ncbi.nlm.nih.gov/geo/series/GSE136nnn/GSE136831/suppl/GSE136831%5FAllCells%2EGeneIDs%2Etxt%2Egz','ids.txt.gz')])
#
# ~/host_home/single-cell-tutorial/NSCLC/../download_scripts/functions.py in download_parallel(args)
#     228
#     229     with ThreadPool(cpus -1 ) as pool:
# --> 230         for result in pool.imap_unordered(download_url, args):
#     231             print('url:', result[0], 'time (s):', result[1])
#
# /opt/python/lib/python3.8/multiprocessing/pool.py in next(self, timeout)
#     854                     self._pool = None
#     855                     raise StopIteration from None
# --> 856                 self._cond.wait(timeout)
#     857                 try:
#     858                     item = self._items.popleft()
#
# /opt/python/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Data

# %% [markdown]
# #### GSE123902

# %%
meta_IV
# Out:
# {'title': {'GSM3516662': 'MSK_LX653_PRIMARY_TUMOUR',
#   'GSM3516663': 'MSK_LX661_PRIMARY_TUMOUR',
#   'GSM3516664': 'MSK_LX666_METASTASIS',
#   'GSM3516665': 'MSK_LX675_PRIMARY_TUMOUR',
#   'GSM3516666': 'MSK_LX675_NORMAL',
#   'GSM3516667': 'MSK_LX676_PRIMARY_TUMOUR',
#   'GSM3516668': 'MSK_LX255B_METASTASIS',
#   'GSM3516669': 'MSK_LX679_PRIMARY_TUMOUR',
#   'GSM3516670': 'MSK_LX680_PRIMARY_TUMOUR',
#   'GSM3516671': 'MSK_LX681_METASTASIS',
#   'GSM3516672': 'MSK_LX682_PRIMARY_TUMOUR',
#   'GSM3516673': 'MSK_LX682_NORMAL',
#   'GSM3516674': 'MSK_LX684_PRIMARY_TUMOUR',
#   'GSM3516675': 'MSK_LX684_NORMAL',
#   'GSM3516676': 'MSK_LX685_NORMAL',
#   'GSM3516677': 'MSK_LX699_METASTASIS',
#   'GSM3516678': 'MSK_LX701_METASTASIS'},
#  'geo_accession': {'GSM3516662': 'GSM3516662',
#   'GSM3516663': 'GSM3516663',
#   'GSM3516664': 'GSM3516664',
#   'GSM3516665': 'GSM3516665',
#   'GSM3516666': 'GSM3516666',
#   'GSM3516667': 'GSM3516667',
#   'GSM3516668': 'GSM3516668',
#   'GSM3516669': 'GSM3516669',
#   'GSM3516670': 'GSM3516670',
#   'GSM3516671': 'GSM3516671',
#   'GSM3516672': 'GSM3516672',
#   'GSM3516673': 'GSM3516673',
#   'GSM3516674': 'GSM3516674',
#   'GSM3516675': 'GSM3516675',
#   'GSM3516676': 'GSM3516676',
#   'GSM3516677': 'GSM3516677',
#   'GSM3516678': 'GSM3516678'},
#  'status': {'GSM3516662': 'Public on Jan 14 2020',
#   'GSM3516663': 'Public on Jan 14 2020',
#   'GSM3516664': 'Public on Jan 14 2020',
#   'GSM3516665': 'Public on Jan 14 2020',
#   'GSM3516666': 'Public on Jan 14 2020',
#   'GSM3516667': 'Public on Jan 14 2020',
#   'GSM3516668': 'Public on Jan 14 2020',
#   'GSM3516669': 'Public on Jan 14 2020',
#   'GSM3516670': 'Public on Jan 14 2020',
#   'GSM3516671': 'Public on Jan 14 2020',
#   'GSM3516672': 'Public on Jan 14 2020',
#   'GSM3516673': 'Public on Jan 14 2020',
#   'GSM3516674': 'Public on Jan 14 2020',
#   'GSM3516675': 'Public on Jan 14 2020',
#   'GSM3516676': 'Public on Jan 14 2020',
#   'GSM3516677': 'Public on Jan 14 2020',
#   'GSM3516678': 'Public on Jan 14 2020'},
#  'submission_date': {'GSM3516662': 'Dec 16 2018',
#   'GSM3516663': 'Dec 16 2018',
#   'GSM3516664': 'Dec 16 2018',
#   'GSM3516665': 'Dec 16 2018',
#   'GSM3516666': 'Dec 16 2018',
#   'GSM3516667': 'Dec 16 2018',
#   'GSM3516668': 'Dec 16 2018',
#   'GSM3516669': 'Dec 16 2018',
#   'GSM3516670': 'Dec 16 2018',
#   'GSM3516671': 'Dec 16 2018',
#   'GSM3516672': 'Dec 16 2018',
#   'GSM3516673': 'Dec 16 2018',
#   'GSM3516674': 'Dec 16 2018',
#   'GSM3516675': 'Dec 16 2018',
#   'GSM3516676': 'Dec 16 2018',
#   'GSM3516677': 'Dec 16 2018',
#   'GSM3516678': 'Dec 16 2018'},
#  'last_update_date': {'GSM3516662': 'Jan 14 2020',
#   'GSM3516663': 'Jan 14 2020',
#   'GSM3516664': 'Jan 14 2020',
#   'GSM3516665': 'Jan 14 2020',
#   'GSM3516666': 'Jan 14 2020',
#   'GSM3516667': 'Jan 14 2020',
#   'GSM3516668': 'Jan 14 2020',
#   'GSM3516669': 'Jan 14 2020',
#   'GSM3516670': 'Jan 14 2020',
#   'GSM3516671': 'Jan 14 2020',
#   'GSM3516672': 'Jan 14 2020',
#   'GSM3516673': 'Jan 14 2020',
#   'GSM3516674': 'Jan 14 2020',
#   'GSM3516675': 'Jan 14 2020',
#   'GSM3516676': 'Jan 14 2020',
#   'GSM3516677': 'Jan 14 2020',
#   'GSM3516678': 'Jan 14 2020'},
#  'type': {'GSM3516662': 'SRA',
#   'GSM3516663': 'SRA',
#   'GSM3516664': 'SRA',
#   'GSM3516665': 'SRA',
#   'GSM3516666': 'SRA',
#   'GSM3516667': 'SRA',
#   'GSM3516668': 'SRA',
#   'GSM3516669': 'SRA',
#   'GSM3516670': 'SRA',
#   'GSM3516671': 'SRA',
#   'GSM3516672': 'SRA',
#   'GSM3516673': 'SRA',
#   'GSM3516674': 'SRA',
#   'GSM3516675': 'SRA',
#   'GSM3516676': 'SRA',
#   'GSM3516677': 'SRA',
#   'GSM3516678': 'SRA'},
#  'channel_count': {'GSM3516662': '1',
#   'GSM3516663': '1',
#   'GSM3516664': '1',
#   'GSM3516665': '1',
#   'GSM3516666': '1',
#   'GSM3516667': '1',
#   'GSM3516668': '1',
#   'GSM3516669': '1',
#   'GSM3516670': '1',
#   'GSM3516671': '1',
#   'GSM3516672': '1',
#   'GSM3516673': '1',
#   'GSM3516674': '1',
#   'GSM3516675': '1',
#   'GSM3516676': '1',
#   'GSM3516677': '1',
#   'GSM3516678': '1'},
#  'source_name_ch1': {'GSM3516662': 'Patient primary lung adenocarcinoma',
#   'GSM3516663': 'Patient primary lung adenocarcinoma',
#   'GSM3516664': 'Patient primary lung adenocarcinoma metastasis to BONE',
#   'GSM3516665': 'Patient primary lung adenocarcinoma',
#   'GSM3516666': 'Patient adjacent non-tumour involved lung',
#   'GSM3516667': 'Patient primary lung adenocarcinoma',
#   'GSM3516668': 'Patient primary lung adenocarcinoma metastasis to BRAIN',
#   'GSM3516669': 'Patient primary lung adenocarcinoma',
#   'GSM3516670': 'Patient primary lung adenocarcinoma',
#   'GSM3516671': 'Patient primary lung adenocarcinoma metastasis to BRAIN',
#   'GSM3516672': 'Patient primary lung adenocarcinoma',
#   'GSM3516673': 'Patient adjacent non-tumour involved lung',
#   'GSM3516674': 'Patient primary lung adenocarcinoma',
#   'GSM3516675': 'Patient adjacent non-tumour involved lung',
#   'GSM3516676': 'Patient adjacent non-tumour involved lung',
#   'GSM3516677': 'Patient primary lung adenocarcinoma metastasis to ADRENAL',
#   'GSM3516678': 'Patient primary lung adenocarcinoma metastasis to BRAIN'},
#  'organism_ch1': {'GSM3516662': 'Homo sapiens',
#   'GSM3516663': 'Homo sapiens',
#   'GSM3516664': 'Homo sapiens',
#   'GSM3516665': 'Homo sapiens',
#   'GSM3516666': 'Homo sapiens',
#   'GSM3516667': 'Homo sapiens',
#   'GSM3516668': 'Homo sapiens',
#   'GSM3516669': 'Homo sapiens',
#   'GSM3516670': 'Homo sapiens',
#   'GSM3516671': 'Homo sapiens',
#   'GSM3516672': 'Homo sapiens',
#   'GSM3516673': 'Homo sapiens',
#   'GSM3516674': 'Homo sapiens',
#   'GSM3516675': 'Homo sapiens',
#   'GSM3516676': 'Homo sapiens',
#   'GSM3516677': 'Homo sapiens',
#   'GSM3516678': 'Homo sapiens'},
#  'taxid_ch1': {'GSM3516662': '9606',
#   'GSM3516663': '9606',
#   'GSM3516664': '9606',
#   'GSM3516665': '9606',
#   'GSM3516666': '9606',
#   'GSM3516667': '9606',
#   'GSM3516668': '9606',
#   'GSM3516669': '9606',
#   'GSM3516670': '9606',
#   'GSM3516671': '9606',
#   'GSM3516672': '9606',
#   'GSM3516673': '9606',
#   'GSM3516674': '9606',
#   'GSM3516675': '9606',
#   'GSM3516676': '9606',
#   'GSM3516677': '9606',
#   'GSM3516678': '9606'},
#  'tissue': {'GSM3516662': 'Patient primary lung adenocarcinoma',
#   'GSM3516663': 'Patient primary lung adenocarcinoma',
#   'GSM3516664': 'Patient primary lung adenocarcinoma metastasis to BONE',
#   'GSM3516665': 'Patient primary lung adenocarcinoma',
#   'GSM3516666': 'Patient adjacent non-tumour involved lung',
#   'GSM3516667': 'Patient primary lung adenocarcinoma',
#   'GSM3516668': 'Patient primary lung adenocarcinoma metastasis to BRAIN',
#   'GSM3516669': 'Patient primary lung adenocarcinoma',
#   'GSM3516670': 'Patient primary lung adenocarcinoma',
#   'GSM3516671': 'Patient primary lung adenocarcinoma metastasis to BRAIN',
#   'GSM3516672': 'Patient primary lung adenocarcinoma',
#   'GSM3516673': 'Patient adjacent non-tumour involved lung',
#   'GSM3516674': 'Patient primary lung adenocarcinoma',
#   'GSM3516675': 'Patient adjacent non-tumour involved lung',
#   'GSM3516676': 'Patient adjacent non-tumour involved lung',
#   'GSM3516677': 'Patient primary lung adenocarcinoma metastasis to ADRENAL',
#   'GSM3516678': 'Patient primary lung adenocarcinoma metastasis to BRAIN'},
#  'Stage': {'GSM3516662': '1A',
#   'GSM3516663': '1A',
#   'GSM3516664': 'IV',
#   'GSM3516665': 'IV',
#   'GSM3516666': 'na',
#   'GSM3516667': '1A',
#   'GSM3516668': 'IV',
#   'GSM3516669': 'IIA',
#   'GSM3516670': 'IB',
#   'GSM3516671': 'IV',
#   'GSM3516672': 'IB',
#   'GSM3516673': 'na',
#   'GSM3516674': 'IA',
#   'GSM3516675': 'na',
#   'GSM3516676': 'na',
#   'GSM3516677': 'IV',
#   'GSM3516678': 'IV'},
#  'diagnosis': {'GSM3516662': 'Lung Adenocarcinoma',
#   'GSM3516663': 'Lung Adenocarcinoma',
#   'GSM3516664': 'Lung Adenocarcinoma',
#   'GSM3516665': 'Lung Adenocarcinoma',
#   'GSM3516666': 'non-tumour involved lung',
#   'GSM3516667': 'Lung Adenocarcinoma',
#   'GSM3516668': 'Lung Adenocarcinoma',
#   'GSM3516669': 'Lung Adenocarcinoma',
#   'GSM3516670': 'Lung Adenocarcinom + Large Cell Neuroendocrine Carcinoma',
#   'GSM3516671': 'Lung Adenocarcinoma',
#   'GSM3516672': 'Lung Adenocarcinoma',
#   'GSM3516673': 'non-tumour involved lung',
#   'GSM3516674': 'Lung Adenocarcinoma',
#   'GSM3516675': 'non-tumour involved lung',
#   'GSM3516676': 'non-tumour involved lung',
#   'GSM3516677': 'Lung Adenocarcinoma',
#   'GSM3516678': 'Lung Adenocarcinoma'},
#  'chemotherapy': {'GSM3516662': 'No',
#   'GSM3516663': 'No',
#   'GSM3516664': 'Yes',
#   'GSM3516665': 'No',
#   'GSM3516666': 'No',
#   'GSM3516667': 'No',
#   'GSM3516668': 'Yes',
#   'GSM3516669': 'Yes',
#   'GSM3516670': 'No',
#   'GSM3516671': 'Yes',
#   'GSM3516672': 'No',
#   'GSM3516673': 'No',
#   'GSM3516674': 'No',
#   'GSM3516675': 'No',
#   'GSM3516676': 'No',
#   'GSM3516677': 'Yes',
#   'GSM3516678': 'Yes'},
#  'molecule_ch1': {'GSM3516662': 'polyA RNA',
#   'GSM3516663': 'polyA RNA',
#   'GSM3516664': 'polyA RNA',
#   'GSM3516665': 'polyA RNA',
#   'GSM3516666': 'polyA RNA',
#   'GSM3516667': 'polyA RNA',
#   'GSM3516668': 'polyA RNA',
#   'GSM3516669': 'polyA RNA',
#   'GSM3516670': 'polyA RNA',
#   'GSM3516671': 'polyA RNA',
#   'GSM3516672': 'polyA RNA',
#   'GSM3516673': 'polyA RNA',
#   'GSM3516674': 'polyA RNA',
#   'GSM3516675': 'polyA RNA',
#   'GSM3516676': 'polyA RNA',
#   'GSM3516677': 'polyA RNA',
#   'GSM3516678': 'polyA RNA'},
#  'extract_protocol_ch1': {},
#  'description': {'GSM3516662': 'Barcoded single cells',
#   'GSM3516663': 'Barcoded single cells',
#   'GSM3516664': 'Barcoded single cells',
#   'GSM3516665': 'Barcoded single cells',
#   'GSM3516666': 'Barcoded single cells',
#   'GSM3516667': 'Barcoded single cells',
#   'GSM3516668': 'Barcoded single cells',
#   'GSM3516669': 'Barcoded single cells',
#   'GSM3516670': 'Barcoded single cells',
#   'GSM3516671': 'Barcoded single cells',
#   'GSM3516672': 'Barcoded single cells',
#   'GSM3516673': 'Barcoded single cells',
#   'GSM3516674': 'Barcoded single cells',
#   'GSM3516675': 'Barcoded single cells',
#   'GSM3516676': 'Barcoded single cells',
#   'GSM3516677': 'Barcoded single cells',
#   'GSM3516678': 'Barcoded single cells'},
#  'data_processing': {},
#  'platform_id': {'GSM3516662': 'GPL16791',
#   'GSM3516663': 'GPL16791',
#   'GSM3516664': 'GPL16791',
#   'GSM3516665': 'GPL16791',
#   'GSM3516666': 'GPL16791',
#   'GSM3516667': 'GPL16791',
#   'GSM3516668': 'GPL16791',
#   'GSM3516669': 'GPL16791',
#   'GSM3516670': 'GPL16791',
#   'GSM3516671': 'GPL16791',
#   'GSM3516672': 'GPL16791',
#   'GSM3516673': 'GPL16791',
#   'GSM3516674': 'GPL16791',
#   'GSM3516675': 'GPL16791',
#   'GSM3516676': 'GPL16791',
#   'GSM3516677': 'GPL16791',
#   'GSM3516678': 'GPL16791'},
#  'contact_name': {'GSM3516662': 'Ashley M Laughney',
#   'GSM3516663': 'Ashley M Laughney',
#   'GSM3516664': 'Ashley M Laughney',
#   'GSM3516665': 'Ashley M Laughney',
#   'GSM3516666': 'Ashley M Laughney',
#   'GSM3516667': 'Ashley M Laughney',
#   'GSM3516668': 'Ashley M Laughney',
#   'GSM3516669': 'Ashley M Laughney',
#   'GSM3516670': 'Ashley M Laughney',
#   'GSM3516671': 'Ashley M Laughney',
#   'GSM3516672': 'Ashley M Laughney',
#   'GSM3516673': 'Ashley M Laughney',
#   'GSM3516674': 'Ashley M Laughney',
#   'GSM3516675': 'Ashley M Laughney',
#   'GSM3516676': 'Ashley M Laughney',
#   'GSM3516677': 'Ashley M Laughney',
#   'GSM3516678': 'Ashley M Laughney'},
#  'contact_email': {'GSM3516662': 'ashley.laughney@gmail.com',
#   'GSM3516663': 'ashley.laughney@gmail.com',
#   'GSM3516664': 'ashley.laughney@gmail.com',
#   'GSM3516665': 'ashley.laughney@gmail.com',
#   'GSM3516666': 'ashley.laughney@gmail.com',
#   'GSM3516667': 'ashley.laughney@gmail.com',
#   'GSM3516668': 'ashley.laughney@gmail.com',
#   'GSM3516669': 'ashley.laughney@gmail.com',
#   'GSM3516670': 'ashley.laughney@gmail.com',
#   'GSM3516671': 'ashley.laughney@gmail.com',
#   'GSM3516672': 'ashley.laughney@gmail.com',
#   'GSM3516673': 'ashley.laughney@gmail.com',
#   'GSM3516674': 'ashley.laughney@gmail.com',
#   'GSM3516675': 'ashley.laughney@gmail.com',
#   'GSM3516676': 'ashley.laughney@gmail.com',
#   'GSM3516677': 'ashley.laughney@gmail.com',
#   'GSM3516678': 'ashley.laughney@gmail.com'},
#  'contact_laboratory': {'GSM3516662': 'Laughney Lab',
#   'GSM3516663': 'Laughney Lab',
#   'GSM3516664': 'Laughney Lab',
#   'GSM3516665': 'Laughney Lab',
#   'GSM3516666': 'Laughney Lab',
#   'GSM3516667': 'Laughney Lab',
#   'GSM3516668': 'Laughney Lab',
#   'GSM3516669': 'Laughney Lab',
#   'GSM3516670': 'Laughney Lab',
#   'GSM3516671': 'Laughney Lab',
#   'GSM3516672': 'Laughney Lab',
#   'GSM3516673': 'Laughney Lab',
#   'GSM3516674': 'Laughney Lab',
#   'GSM3516675': 'Laughney Lab',
#   'GSM3516676': 'Laughney Lab',
#   'GSM3516677': 'Laughney Lab',
#   'GSM3516678': 'Laughney Lab'},
#  'contact_department': {'GSM3516662': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516663': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516664': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516665': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516666': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516667': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516668': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516669': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516670': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516671': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516672': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516673': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516674': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516675': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516676': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516677': 'Physiology  Biophysics and Systems Biology',
#   'GSM3516678': 'Physiology  Biophysics and Systems Biology'},
#  'contact_institute': {'GSM3516662': 'Weill Cornell Medicine',
#   'GSM3516663': 'Weill Cornell Medicine',
#   'GSM3516664': 'Weill Cornell Medicine',
#   'GSM3516665': 'Weill Cornell Medicine',
#   'GSM3516666': 'Weill Cornell Medicine',
#   'GSM3516667': 'Weill Cornell Medicine',
#   'GSM3516668': 'Weill Cornell Medicine',
#   'GSM3516669': 'Weill Cornell Medicine',
#   'GSM3516670': 'Weill Cornell Medicine',
#   'GSM3516671': 'Weill Cornell Medicine',
#   'GSM3516672': 'Weill Cornell Medicine',
#   'GSM3516673': 'Weill Cornell Medicine',
#   'GSM3516674': 'Weill Cornell Medicine',
#   'GSM3516675': 'Weill Cornell Medicine',
#   'GSM3516676': 'Weill Cornell Medicine',
#   'GSM3516677': 'Weill Cornell Medicine',
#   'GSM3516678': 'Weill Cornell Medicine'},
#  'contact_address': {'GSM3516662': '413 East 69th Street',
#   'GSM3516663': '413 East 69th Street',
#   'GSM3516664': '413 East 69th Street',
#   'GSM3516665': '413 East 69th Street',
#   'GSM3516666': '413 East 69th Street',
#   'GSM3516667': '413 East 69th Street',
#   'GSM3516668': '413 East 69th Street',
#   'GSM3516669': '413 East 69th Street',
#   'GSM3516670': '413 East 69th Street',
#   'GSM3516671': '413 East 69th Street',
#   'GSM3516672': '413 East 69th Street',
#   'GSM3516673': '413 East 69th Street',
#   'GSM3516674': '413 East 69th Street',
#   'GSM3516675': '413 East 69th Street',
#   'GSM3516676': '413 East 69th Street',
#   'GSM3516677': '413 East 69th Street',
#   'GSM3516678': '413 East 69th Street'},
#  'contact_city': {'GSM3516662': 'NEW YORK',
#   'GSM3516663': 'NEW YORK',
#   'GSM3516664': 'NEW YORK',
#   'GSM3516665': 'NEW YORK',
#   'GSM3516666': 'NEW YORK',
#   'GSM3516667': 'NEW YORK',
#   'GSM3516668': 'NEW YORK',
#   'GSM3516669': 'NEW YORK',
#   'GSM3516670': 'NEW YORK',
#   'GSM3516671': 'NEW YORK',
#   'GSM3516672': 'NEW YORK',
#   'GSM3516673': 'NEW YORK',
#   'GSM3516674': 'NEW YORK',
#   'GSM3516675': 'NEW YORK',
#   'GSM3516676': 'NEW YORK',
#   'GSM3516677': 'NEW YORK',
#   'GSM3516678': 'NEW YORK'},
#  'contact_state': {'GSM3516662': 'New York',
#   'GSM3516663': 'New York',
#   'GSM3516664': 'New York',
#   'GSM3516665': 'New York',
#   'GSM3516666': 'New York',
#   'GSM3516667': 'New York',
#   'GSM3516668': 'New York',
#   'GSM3516669': 'New York',
#   'GSM3516670': 'New York',
#   'GSM3516671': 'New York',
#   'GSM3516672': 'New York',
#   'GSM3516673': 'New York',
#   'GSM3516674': 'New York',
#   'GSM3516675': 'New York',
#   'GSM3516676': 'New York',
#   'GSM3516677': 'New York',
#   'GSM3516678': 'New York'},
#  'contact_zip/postal_code': {'GSM3516662': '10021',
#   'GSM3516663': '10021',
#   'GSM3516664': '10021',
#   'GSM3516665': '10021',
#   'GSM3516666': '10021',
#   'GSM3516667': '10021',
#   'GSM3516668': '10021',
#   'GSM3516669': '10021',
#   'GSM3516670': '10021',
#   'GSM3516671': '10021',
#   'GSM3516672': '10021',
#   'GSM3516673': '10021',
#   'GSM3516674': '10021',
#   'GSM3516675': '10021',
#   'GSM3516676': '10021',
#   'GSM3516677': '10021',
#   'GSM3516678': '10021'},
#  'contact_country': {'GSM3516662': 'USA',
#   'GSM3516663': 'USA',
#   'GSM3516664': 'USA',
#   'GSM3516665': 'USA',
#   'GSM3516666': 'USA',
#   'GSM3516667': 'USA',
#   'GSM3516668': 'USA',
#   'GSM3516669': 'USA',
#   'GSM3516670': 'USA',
#   'GSM3516671': 'USA',
#   'GSM3516672': 'USA',
#   'GSM3516673': 'USA',
#   'GSM3516674': 'USA',
#   'GSM3516675': 'USA',
#   'GSM3516676': 'USA',
#   'GSM3516677': 'USA',
#   'GSM3516678': 'USA'},
#  'instrument_model': {'GSM3516662': 'Illumina HiSeq 2500',
#   'GSM3516663': 'Illumina HiSeq 2500',
#   'GSM3516664': 'Illumina HiSeq 2500',
#   'GSM3516665': 'Illumina HiSeq 2500',
#   'GSM3516666': 'Illumina HiSeq 2500',
#   'GSM3516667': 'Illumina HiSeq 2500',
#   'GSM3516668': 'Illumina HiSeq 2500',
#   'GSM3516669': 'Illumina HiSeq 2500',
#   'GSM3516670': 'Illumina HiSeq 2500',
#   'GSM3516671': 'Illumina HiSeq 2500',
#   'GSM3516672': 'Illumina HiSeq 2500',
#   'GSM3516673': 'Illumina HiSeq 2500',
#   'GSM3516674': 'Illumina HiSeq 2500',
#   'GSM3516675': 'Illumina HiSeq 2500',
#   'GSM3516676': 'Illumina HiSeq 2500',
#   'GSM3516677': 'Illumina HiSeq 2500',
#   'GSM3516678': 'Illumina HiSeq 2500'},
#  'library_selection': {'GSM3516662': 'cDNA',
#   'GSM3516663': 'cDNA',
#   'GSM3516664': 'cDNA',
#   'GSM3516665': 'cDNA',
#   'GSM3516666': 'cDNA',
#   'GSM3516667': 'cDNA',
#   'GSM3516668': 'cDNA',
#   'GSM3516669': 'cDNA',
#   'GSM3516670': 'cDNA',
#   'GSM3516671': 'cDNA',
#   'GSM3516672': 'cDNA',
#   'GSM3516673': 'cDNA',
#   'GSM3516674': 'cDNA',
#   'GSM3516675': 'cDNA',
#   'GSM3516676': 'cDNA',
#   'GSM3516677': 'cDNA',
#   'GSM3516678': 'cDNA'},
#  'library_source': {'GSM3516662': 'transcriptomic',
#   'GSM3516663': 'transcriptomic',
#   'GSM3516664': 'transcriptomic',
#   'GSM3516665': 'transcriptomic',
#   'GSM3516666': 'transcriptomic',
#   'GSM3516667': 'transcriptomic',
#   'GSM3516668': 'transcriptomic',
#   'GSM3516669': 'transcriptomic',
#   'GSM3516670': 'transcriptomic',
#   'GSM3516671': 'transcriptomic',
#   'GSM3516672': 'transcriptomic',
#   'GSM3516673': 'transcriptomic',
#   'GSM3516674': 'transcriptomic',
#   'GSM3516675': 'transcriptomic',
#   'GSM3516676': 'transcriptomic',
#   'GSM3516677': 'transcriptomic',
#   'GSM3516678': 'transcriptomic'},
#  'library_strategy': {'GSM3516662': 'RNA-Seq',
#   'GSM3516663': 'RNA-Seq',
#   'GSM3516664': 'RNA-Seq',
#   'GSM3516665': 'RNA-Seq',
#   'GSM3516666': 'RNA-Seq',
#   'GSM3516667': 'RNA-Seq',
#   'GSM3516668': 'RNA-Seq',
#   'GSM3516669': 'RNA-Seq',
#   'GSM3516670': 'RNA-Seq',
#   'GSM3516671': 'RNA-Seq',
#   'GSM3516672': 'RNA-Seq',
#   'GSM3516673': 'RNA-Seq',
#   'GSM3516674': 'RNA-Seq',
#   'GSM3516675': 'RNA-Seq',
#   'GSM3516676': 'RNA-Seq',
#   'GSM3516677': 'RNA-Seq',
#   'GSM3516678': 'RNA-Seq'},
#  'relation': {},
#  'supplementary_file_1': {'GSM3516662': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516662/suppl/GSM3516662_MSK_LX653_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516663': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516663/suppl/GSM3516663_MSK_LX661_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516664': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516664/suppl/GSM3516664_MSK_LX666_METASTASIS_dense.csv.gz',
#   'GSM3516665': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516665/suppl/GSM3516665_MSK_LX675_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516666': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516666/suppl/GSM3516666_MSK_LX675_NORMAL_dense.csv.gz',
#   'GSM3516667': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516667/suppl/GSM3516667_MSK_LX676_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516668': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516668/suppl/GSM3516668_MSK_LX255B_METASTASIS_dense.csv.gz',
#   'GSM3516669': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516669/suppl/GSM3516669_MSK_LX679_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516670': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516670/suppl/GSM3516670_MSK_LX680_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516671': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516671/suppl/GSM3516671_MSK_LX681_METASTASIS_dense.csv.gz',
#   'GSM3516672': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516672/suppl/GSM3516672_MSK_LX682_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516673': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516673/suppl/GSM3516673_MSK_LX682_NORMAL_dense.csv.gz',
#   'GSM3516674': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516674/suppl/GSM3516674_MSK_LX684_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516675': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516675/suppl/GSM3516675_MSK_LX684_NORMAL_dense.csv.gz',
#   'GSM3516676': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516676/suppl/GSM3516676_MSK_LX685_NORMAL_dense.csv.gz',
#   'GSM3516677': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516677/suppl/GSM3516677_MSK_LX699_METASTASIS_dense.csv.gz',
#   'GSM3516678': 'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516678/suppl/GSM3516678_MSK_LX701_METASTASIS_dense.csv.gz'},
#  'series_id': {},
#  'data_row_count': {'GSM3516662': '0',
#   'GSM3516663': '0',
#   'GSM3516664': '0',
#   'GSM3516665': '0',
#   'GSM3516666': '0',
#   'GSM3516667': '0',
#   'GSM3516668': '0',
#   'GSM3516669': '0',
#   'GSM3516670': '0',
#   'GSM3516671': '0',
#   'GSM3516672': '0',
#   'GSM3516673': '0',
#   'GSM3516674': '0',
#   'GSM3516675': '0',
#   'GSM3516676': '0',
#   'GSM3516677': '0',
#   'GSM3516678': '0'},
#  'sup_type': {'GSM3516662': ' csv of cells x genes unnormalized',
#   'GSM3516663': ' csv of cells x genes unnormalized',
#   'GSM3516664': ' csv of cells x genes unnormalized',
#   'GSM3516665': ' csv of cells x genes unnormalized',
#   'GSM3516666': ' csv of cells x genes unnormalized',
#   'GSM3516667': ' csv of cells x genes unnormalized',
#   'GSM3516668': ' csv of cells x genes unnormalized',
#   'GSM3516669': ' csv of cells x genes unnormalized',
#   'GSM3516670': ' csv of cells x genes unnormalized',
#   'GSM3516671': ' csv of cells x genes unnormalized',
#   'GSM3516672': ' csv of cells x genes unnormalized',
#   'GSM3516673': ' csv of cells x genes unnormalized',
#   'GSM3516674': ' csv of cells x genes unnormalized',
#   'GSM3516675': ' csv of cells x genes unnormalized',
#   'GSM3516676': ' csv of cells x genes unnormalized',
#   'GSM3516677': ' csv of cells x genes unnormalized',
#   'GSM3516678': ' csv of cells x genes unnormalized'},
#  'local_path': {'GSM3516662': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516662_MSK_LX653_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516663': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516663_MSK_LX661_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516664': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516664_MSK_LX666_METASTASIS_dense.csv.gz',
#   'GSM3516665': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516665_MSK_LX675_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516666': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516666_MSK_LX675_NORMAL_dense.csv.gz',
#   'GSM3516667': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516667_MSK_LX676_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516668': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516668_MSK_LX255B_METASTASIS_dense.csv.gz',
#   'GSM3516669': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516669_MSK_LX679_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516670': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516670_MSK_LX680_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516671': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516671_MSK_LX681_METASTASIS_dense.csv.gz',
#   'GSM3516672': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516672_MSK_LX682_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516673': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516673_MSK_LX682_NORMAL_dense.csv.gz',
#   'GSM3516674': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516674_MSK_LX684_PRIMARY_TUMOUR_dense.csv.gz',
#   'GSM3516675': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516675_MSK_LX684_NORMAL_dense.csv.gz',
#   'GSM3516676': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516676_MSK_LX685_NORMAL_dense.csv.gz',
#   'GSM3516677': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516677_MSK_LX699_METASTASIS_dense.csv.gz',
#   'GSM3516678': '/root/datos/maestria/netopaas/lung_scRNA/GSE123902/GSM3516678_MSK_LX701_METASTASIS_dense.csv.gz'},
#  'genome_build': {'GSM3516662': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516663': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516664': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516665': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516666': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516667': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516668': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516669': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516670': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516671': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516672': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516673': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516674': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516675': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516676': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516677': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides',
#   'GSM3516678': ' hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides'}}

# %%
gse_IV= 'GSE123902' # lung metastasis 7 actual tumor
meta_IV = get_geo_exprs(gse_IV)

urls = list(meta_IV['supplementary_file_1'].values())
paths = list(meta_IV['local_path'].values())
args_IV = zip(urls, paths)
# Out:
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']
# ['The Sequence Quality Control (SEQC) package18 was utilized for de-multiplexing, STAR alignment, implementation of cell barcode and multi-alignment correction, and the generation of a raw digital expression matrix by collapsing groups of reads with the same unique molecular identifier (UMI), cell barcode and gene annotation. Alignment to the hg38 annotation was restricted to transcribed, polyadenylated RNA of length > 200 nucleotides (gene biotypes accessible by 3’ mRNA sequencing technologies) to increase mapping specificity.', 'Genome_build: hg38 annotation restricted to transcribed, polyadenylated RNA of length > 200 nucleotides', 'Supplementary_files_format_and_content: csv of cells x genes unnormalized']

# %%
meta_IV['geo_accession']
# Out:
# {'GSM3516662': 'GSM3516662',
#  'GSM3516663': 'GSM3516663',
#  'GSM3516664': 'GSM3516664',
#  'GSM3516665': 'GSM3516665',
#  'GSM3516666': 'GSM3516666',
#  'GSM3516667': 'GSM3516667',
#  'GSM3516668': 'GSM3516668',
#  'GSM3516669': 'GSM3516669',
#  'GSM3516670': 'GSM3516670',
#  'GSM3516671': 'GSM3516671',
#  'GSM3516672': 'GSM3516672',
#  'GSM3516673': 'GSM3516673',
#  'GSM3516674': 'GSM3516674',
#  'GSM3516675': 'GSM3516675',
#  'GSM3516676': 'GSM3516676',
#  'GSM3516677': 'GSM3516677',
#  'GSM3516678': 'GSM3516678'}

# %%
download_parallel(args_IV, gse_IV)
# Out:
# CPUS:  26
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516662/suppl/GSM3516662_MSK_LX653_PRIMARY_TUMOUR_dense.csv.gz time (s): 1.8080072402954102
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516670/suppl/GSM3516670_MSK_LX680_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.0990450382232666
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516664/suppl/GSM3516664_MSK_LX666_METASTASIS_dense.csv.gz time (s): 2.1689655780792236
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516675/suppl/GSM3516675_MSK_LX684_NORMAL_dense.csv.gz time (s): 2.200122833251953
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516676/suppl/GSM3516676_MSK_LX685_NORMAL_dense.csv.gz time (s): 2.2731893062591553
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516669/suppl/GSM3516669_MSK_LX679_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.4018094539642334
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516674/suppl/GSM3516674_MSK_LX684_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.476111650466919
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516678/suppl/GSM3516678_MSK_LX701_METASTASIS_dense.csv.gz time (s): 2.5878591537475586
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516666/suppl/GSM3516666_MSK_LX675_NORMAL_dense.csv.gz time (s): 3.0364036560058594
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516668/suppl/GSM3516668_MSK_LX255B_METASTASIS_dense.csv.gz time (s): 3.095433235168457
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516677/suppl/GSM3516677_MSK_LX699_METASTASIS_dense.csv.gz time (s): 3.0982189178466797
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516663/suppl/GSM3516663_MSK_LX661_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.2621471881866455
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516665/suppl/GSM3516665_MSK_LX675_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.5058815479278564
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516667/suppl/GSM3516667_MSK_LX676_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.5441017150878906
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516673/suppl/GSM3516673_MSK_LX682_NORMAL_dense.csv.gz time (s): 4.357524633407593
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516671/suppl/GSM3516671_MSK_LX681_METASTASIS_dense.csv.gz time (s): 4.735802412033081
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516672/suppl/GSM3516672_MSK_LX682_PRIMARY_TUMOUR_dense.csv.gz time (s): 5.3966827392578125

# %% [markdown]
# #### GSE136831

# %%
gse_both= 'GSE136831' # lung metastasis 7 actual tumor
meta_both = get_geo_exprs(gse_both)

urls = list(meta_both['supplementary_file_1'].values())
paths = list(meta_both['local_path'].values())
args_IV = zip(urls, paths)

# %%
list(meta_both['supplementary_file_1'].values())
# Out:
# ['ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058900/suppl/GSM4058900_133C-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058901/suppl/GSM4058901_137C-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058902/suppl/GSM4058902_034C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058903/suppl/GSM4058903_218C-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058904/suppl/GSM4058904_226C-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058905/suppl/GSM4058905_244C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058906/suppl/GSM4058906_098C-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058907/suppl/GSM4058907_465C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058908/suppl/GSM4058908_396C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058909/suppl/GSM4058909_296C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058910/suppl/GSM4058910_208C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058911/suppl/GSM4058911_022C-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058912/suppl/GSM4058912_160C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058913/suppl/GSM4058913_092C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058914/suppl/GSM4058914_439C-b.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058915/suppl/GSM4058915_065C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058916/suppl/GSM4058916_388C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058917/suppl/GSM4058917_192C-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058918/suppl/GSM4058918_483C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058919/suppl/GSM4058919_001C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058920/suppl/GSM4058920_002C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058921/suppl/GSM4058921_003C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058922/suppl/GSM4058922_454C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058923/suppl/GSM4058923_253C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058924/suppl/GSM4058924_484C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058925/suppl/GSM4058925_081C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058926/suppl/GSM4058926_137C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058927/suppl/GSM4058927_084C.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058928/suppl/GSM4058928_152CO-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058929/suppl/GSM4058929_153CO-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058930/suppl/GSM4058930_178CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058931/suppl/GSM4058931_184CO-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058932/suppl/GSM4058932_186CO-b.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058933/suppl/GSM4058933_192CO-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058934/suppl/GSM4058934_193CO-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058935/suppl/GSM4058935_194CO-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058936/suppl/GSM4058936_207CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058937/suppl/GSM4058937_217CO-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058938/suppl/GSM4058938_23CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058939/suppl/GSM4058939_235CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058940/suppl/GSM4058940_237CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058941/suppl/GSM4058941_238CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058942/suppl/GSM4058942_8CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058943/suppl/GSM4058943_052CO-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058944/suppl/GSM4058944_056CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058945/suppl/GSM4058945_137CO.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058946/suppl/GSM4058946_210I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058947/suppl/GSM4058947_135I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058948/suppl/GSM4058948_138I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058949/suppl/GSM4058949_145I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058950/suppl/GSM4058950_157I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058951/suppl/GSM4058951_166I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058952/suppl/GSM4058952_174I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058953/suppl/GSM4058953_179I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058954/suppl/GSM4058954_209I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058955/suppl/GSM4058955_212I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058956/suppl/GSM4058956_214I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058957/suppl/GSM4058957_221I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058958/suppl/GSM4058958_222I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058959/suppl/GSM4058959_225I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058960/suppl/GSM4058960_228I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058961/suppl/GSM4058961_29I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058962/suppl/GSM4058962_051I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058963/suppl/GSM4058963_025I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058964/suppl/GSM4058964_010I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058965/suppl/GSM4058965_021I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058966/suppl/GSM4058966_022I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058967/suppl/GSM4058967_041I-b.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058968/suppl/GSM4058968_040I-b.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058969/suppl/GSM4058969_47I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058970/suppl/GSM4058970_49I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058971/suppl/GSM4058971_053I-d.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058972/suppl/GSM4058972_59I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058973/suppl/GSM4058973_063I-b.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058974/suppl/GSM4058974_034I-a.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058975/suppl/GSM4058975_123I.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058976/suppl/GSM4058976_158I-b.dgecounts.rds.gz',
#  'ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4058nnn/GSM4058977/suppl/GSM4058977_177I.dgecounts.rds.gz']

# %%
meta_IV['geo_accession']
# Out:
# {'GSM3516662': 'GSM3516662',
#  'GSM3516663': 'GSM3516663',
#  'GSM3516664': 'GSM3516664',
#  'GSM3516665': 'GSM3516665',
#  'GSM3516666': 'GSM3516666',
#  'GSM3516667': 'GSM3516667',
#  'GSM3516668': 'GSM3516668',
#  'GSM3516669': 'GSM3516669',
#  'GSM3516670': 'GSM3516670',
#  'GSM3516671': 'GSM3516671',
#  'GSM3516672': 'GSM3516672',
#  'GSM3516673': 'GSM3516673',
#  'GSM3516674': 'GSM3516674',
#  'GSM3516675': 'GSM3516675',
#  'GSM3516676': 'GSM3516676',
#  'GSM3516677': 'GSM3516677',
#  'GSM3516678': 'GSM3516678'}

# %%
download_parallel(args_IV, gse_IV)
# Out:
# CPUS:  26
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516662/suppl/GSM3516662_MSK_LX653_PRIMARY_TUMOUR_dense.csv.gz time (s): 1.8080072402954102
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516670/suppl/GSM3516670_MSK_LX680_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.0990450382232666
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516664/suppl/GSM3516664_MSK_LX666_METASTASIS_dense.csv.gz time (s): 2.1689655780792236
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516675/suppl/GSM3516675_MSK_LX684_NORMAL_dense.csv.gz time (s): 2.200122833251953
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516676/suppl/GSM3516676_MSK_LX685_NORMAL_dense.csv.gz time (s): 2.2731893062591553
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516669/suppl/GSM3516669_MSK_LX679_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.4018094539642334
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516674/suppl/GSM3516674_MSK_LX684_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.476111650466919
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516678/suppl/GSM3516678_MSK_LX701_METASTASIS_dense.csv.gz time (s): 2.5878591537475586
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516666/suppl/GSM3516666_MSK_LX675_NORMAL_dense.csv.gz time (s): 3.0364036560058594
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516668/suppl/GSM3516668_MSK_LX255B_METASTASIS_dense.csv.gz time (s): 3.095433235168457
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516677/suppl/GSM3516677_MSK_LX699_METASTASIS_dense.csv.gz time (s): 3.0982189178466797
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516663/suppl/GSM3516663_MSK_LX661_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.2621471881866455
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516665/suppl/GSM3516665_MSK_LX675_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.5058815479278564
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516667/suppl/GSM3516667_MSK_LX676_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.5441017150878906
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516673/suppl/GSM3516673_MSK_LX682_NORMAL_dense.csv.gz time (s): 4.357524633407593
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516671/suppl/GSM3516671_MSK_LX681_METASTASIS_dense.csv.gz time (s): 4.735802412033081
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516672/suppl/GSM3516672_MSK_LX682_PRIMARY_TUMOUR_dense.csv.gz time (s): 5.3966827392578125

# %% [markdown]
# #### GSE99254

# %%
gse_both= 'GSE99254' # lung metastasis 7 actual tumor
meta_both = get_geo_exprs(gse_both)

urls = list(meta_both['supplementary_file_1'].values())
paths = list(meta_both['local_path'].values())
args_IV = zip(urls, paths)

# %%
list(meta_both['supplementary_file_1'].values())
# Out:
# ['NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE']

# %%
download_parallel(args_IV, gse_IV)
# Out:
# CPUS:  26
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516662/suppl/GSM3516662_MSK_LX653_PRIMARY_TUMOUR_dense.csv.gz time (s): 1.8080072402954102
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516670/suppl/GSM3516670_MSK_LX680_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.0990450382232666
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516664/suppl/GSM3516664_MSK_LX666_METASTASIS_dense.csv.gz time (s): 2.1689655780792236
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516675/suppl/GSM3516675_MSK_LX684_NORMAL_dense.csv.gz time (s): 2.200122833251953
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516676/suppl/GSM3516676_MSK_LX685_NORMAL_dense.csv.gz time (s): 2.2731893062591553
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516669/suppl/GSM3516669_MSK_LX679_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.4018094539642334
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516674/suppl/GSM3516674_MSK_LX684_PRIMARY_TUMOUR_dense.csv.gz time (s): 2.476111650466919
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516678/suppl/GSM3516678_MSK_LX701_METASTASIS_dense.csv.gz time (s): 2.5878591537475586
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516666/suppl/GSM3516666_MSK_LX675_NORMAL_dense.csv.gz time (s): 3.0364036560058594
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516668/suppl/GSM3516668_MSK_LX255B_METASTASIS_dense.csv.gz time (s): 3.095433235168457
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516677/suppl/GSM3516677_MSK_LX699_METASTASIS_dense.csv.gz time (s): 3.0982189178466797
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516663/suppl/GSM3516663_MSK_LX661_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.2621471881866455
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516665/suppl/GSM3516665_MSK_LX675_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.5058815479278564
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516667/suppl/GSM3516667_MSK_LX676_PRIMARY_TUMOUR_dense.csv.gz time (s): 3.5441017150878906
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516673/suppl/GSM3516673_MSK_LX682_NORMAL_dense.csv.gz time (s): 4.357524633407593
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516671/suppl/GSM3516671_MSK_LX681_METASTASIS_dense.csv.gz time (s): 4.735802412033081
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM3516nnn/GSM3516672/suppl/GSM3516672_MSK_LX682_PRIMARY_TUMOUR_dense.csv.gz time (s): 5.3966827392578125

# %% [markdown]
# ### Handling gene annotations (some tests)

# %%
gsm = 'GSM3516662_MSK_LX653_PRIMARY_TUMOUR_dense.csv.gz'
adata_IV = pd.read_csv(f'{data_dir}/{gse_IV}/{gsm}')

# %%
adata_IV.index =  adata_IV['Unnamed: 0']
adata_IV = adata_IV.drop(columns='Unnamed: 0')
adata_IV
# Out:
#                  TSPAN6  DPM1  SCYL3  C1ORF112  FGR  CFH  FUCA2  GCLC  NFYA  \
# Unnamed: 0
# 120703436614579       0     0      0         0    0    0      0     0     0
# 120726924712805       0     0      0         0    0    0      0     0     0
# 120772934388134       0     0      0         0    0    0      0     0     0
# 120786758522667       0     0      0         0    0    0      0     0     0
# 120797912811867       0     0      0         0    0    0      0     0     0
# ...                 ...   ...    ...       ...  ...  ...    ...   ...   ...
# 241057699838877       0     0      0         0    0    0      0     0     0
# 241057699907941       0     0      0         0    0    0      0     0     0
# 241114561854197       0     0      0         0    0    0      0     1     0
# 241114562643683       0     0      0         0    0    0      0     0     0
# 241114608199518       0     1      0         0    0    0      0     0     0
#
#                  STPG1  ...  RP11-298A10.1  RP11-180P8.1  RP11-9J18.1  \
# Unnamed: 0              ...
# 120703436614579      0  ...              0             0            0
# 120726924712805      0  ...              0             0            0
# 120772934388134      0  ...              0             0            0
# 120786758522667      0  ...              0             0            0
# 120797912811867      0  ...              0             0            0
# ...                ...  ...            ...           ...          ...
# 241057699838877      0  ...              0             0            0
# 241057699907941      0  ...              0             0            0
# 241114561854197      0  ...              0             0            0
# 241114562643683      0  ...              0             0            0
# 241114608199518      0  ...              0             0            1
#
#                  RP11-151G14.2  RP11-1037J10.1  EXOC3L2  RP11-57A19.7  \
# Unnamed: 0
# 120703436614579              0               0        0             0
# 120726924712805              0               0        0             0
# 120772934388134              0               0        0             0
# 120786758522667              0               0        0             0
# 120797912811867              0               0        0             0
# ...                        ...             ...      ...           ...
# 241057699838877              0               0        0             0
# 241057699907941              0               0        0             0
# 241114561854197              0               0        0             0
# 241114562643683              0               0        0             0
# 241114608199518              0               0        0             0
#
#                  RP11-419I17.1  AC013271.5  RP11-122G18.12
# Unnamed: 0
# 120703436614579              0           0               0
# 120726924712805              0           0               0
# 120772934388134              0           0               0
# 120786758522667              0           0               0
# 120797912811867              0           0               0
# ...                        ...         ...             ...
# 241057699838877              0           0               0
# 241057699907941              0           0               0
# 241114561854197              0           0               0
# 241114562643683              0           0               0
# 241114608199518              0           0               0
#
# [392 rows x 16145 columns]

# %%
gse_I = 'GSE148071' # chinese no raw files
meta_I = get_geo_exprs(gse_I)

urls = list(meta_I['supplementary_file_1'].values())
paths = list(meta_I['local_path'].values())
args_I = zip(urls, paths)

# %%
download_parallel(args_I, gse_I)
# Out:
# CPUS:  26
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453599/suppl/GSM4453599_P24_exp.txt.gz time (s): 1.2470176219940186
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453577/suppl/GSM4453577_P2_exp.txt.gz time (s): 1.3342995643615723
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453587/suppl/GSM4453587_P12_exp.txt.gz time (s): 1.6076200008392334
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453597/suppl/GSM4453597_P22_exp.txt.gz time (s): 1.6947636604309082
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453594/suppl/GSM4453594_P19_exp.txt.gz time (s): 1.9105088710784912
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453595/suppl/GSM4453595_P20_exp.txt.gz time (s): 1.9886648654937744
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453583/suppl/GSM4453583_P8_exp.txt.gz time (s): 2.0728156566619873
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453601/suppl/GSM4453601_P26_exp.txt.gz time (s): 1.1037259101867676
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453588/suppl/GSM4453588_P13_exp.txt.gz time (s): 2.3898000717163086
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453591/suppl/GSM4453591_P16_exp.txt.gz time (s): 2.492403030395508
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453593/suppl/GSM4453593_P18_exp.txt.gz time (s): 2.6143581867218018
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453586/suppl/GSM4453586_P11_exp.txt.gz time (s): 2.7170796394348145
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453589/suppl/GSM4453589_P14_exp.txt.gz time (s): 2.720447063446045
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453602/suppl/GSM4453602_P27_exp.txt.gz time (s): 1.465766191482544
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453581/suppl/GSM4453581_P6_exp.txt.gz time (s): 2.9364960193634033
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453579/suppl/GSM4453579_P4_exp.txt.gz time (s): 3.2711617946624756
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453590/suppl/GSM4453590_P15_exp.txt.gz time (s): 3.2893805503845215
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453605/suppl/GSM4453605_P30_exp.txt.gz time (s): 1.4281909465789795
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453607/suppl/GSM4453607_P32_exp.txt.gz time (s): 1.2803382873535156
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453582/suppl/GSM4453582_P7_exp.txt.gz time (s): 3.4417879581451416
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453580/suppl/GSM4453580_P5_exp.txt.gz time (s): 3.5239155292510986
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453598/suppl/GSM4453598_P23_exp.txt.gz time (s): 3.533515214920044
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453596/suppl/GSM4453596_P21_exp.txt.gz time (s): 3.6082608699798584
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453606/suppl/GSM4453606_P31_exp.txt.gz time (s): 1.6481006145477295
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453603/suppl/GSM4453603_P28_exp.txt.gz time (s): 2.1211557388305664
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453604/suppl/GSM4453604_P29_exp.txt.gz time (s): 2.071453332901001
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453600/suppl/GSM4453600_P25_exp.txt.gz time (s): 3.8805532455444336
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453611/suppl/GSM4453611_P36_exp.txt.gz time (s): 1.3352770805358887
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453609/suppl/GSM4453609_P34_exp.txt.gz time (s): 1.6225659847259521
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453608/suppl/GSM4453608_P33_exp.txt.gz time (s): 1.767401933670044
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453585/suppl/GSM4453585_P10_exp.txt.gz time (s): 4.145767450332642
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453613/suppl/GSM4453613_P38_exp.txt.gz time (s): 1.6459522247314453
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453615/suppl/GSM4453615_P40_exp.txt.gz time (s): 1.475013256072998
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453584/suppl/GSM4453584_P9_exp.txt.gz time (s): 4.517608165740967
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453617/suppl/GSM4453617_P42_exp.txt.gz time (s): 1.4190268516540527
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453610/suppl/GSM4453610_P35_exp.txt.gz time (s): 2.2806265354156494
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453578/suppl/GSM4453578_P3_exp.txt.gz time (s): 5.481846332550049
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453592/suppl/GSM4453592_P17_exp.txt.gz time (s): 5.514392137527466
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453576/suppl/GSM4453576_P1_exp.txt.gz time (s): 5.566208124160767
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453612/suppl/GSM4453612_P37_exp.txt.gz time (s): 2.9692912101745605
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453614/suppl/GSM4453614_P39_exp.txt.gz time (s): 3.228362560272217
# url: ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM4453nnn/GSM4453616/suppl/GSM4453616_P41_exp.txt.gz time (s): 4.971230506896973

# %%
aro = ['ENSG00000125085','ENSG00000125085']

# %%
# %%R -i aro
# # biomaRt::listEnsemblArchives()
# library(biomaRt)
# ensembl <- useEnsembl(biomart = "genes", dataset = "hsapiens_gene_ensembl")
# Out:
# R[write to console]: Error in .processResults(postRes, mart = mart, hostURLsep = sep, fullXmlQuery = fullXmlQuery,  :
#   Query ERROR: caught BioMart::Exception::Usage: Filter NA NOT FOUND
# Error in .processResults(postRes, mart = mart, hostURLsep = sep, fullXmlQuery = fullXmlQuery,  :
#   Query ERROR: caught BioMart::Exception::Usage: Filter NA NOT FOUND

# %%
# %%R -i aro
# aro = unlist(aro)
# ensembl.ann = getBM(attributes = c("ensembl_gene_id",
#                                             "percentage_gene_gc_content",
#                                             "gene_biotype",
#                                             "chromosome_name",
#                                             "external_gene_name"),
#                              filters = "ensembl_gene_id",
#                              values = aro,
#                              mart = ensembl)

# %%
# %R print(ensembl.ann)
# Out:
# [1] ensembl_gene_id            percentage_gene_gc_content
# [3] gene_biotype               chromosome_name
# [5] external_gene_name
# <0 rows> (or 0-length row.names)
# Empty DataFrame
# Columns: [ensembl_gene_id, percentage_gene_gc_content, gene_biotype, chromosome_name, external_gene_name]
# Index: []

# %%
gsm = 'GSM4453580_P5_exp.txt.gz'
adata_I = pd.read_table(f'{data_dir}/{gse_I}/{gsm}')
adata_I = adata_I.transpose()

# %%
adata_I
# Out:
#                 PWP1  FTH1  PERP  RPL37  MT-RNR2  AKR1C3  ATP6V0E1  TPT1  \
# 8_CGCAATGCATCG     2     0     4     66     2006       0         7    25
# 8_GCTCTATAAGTA     2     1     7     36     1867       0         5     9
# 8_GCGCGGACCAGG     2     1     0     50     1509       2         3    13
# 8_CGGTGGCCCGTG     1     9     1     28     1732       1         2    17
# 8_TTCCGCATCTTA     0     0     1     10     2109       0         4    14
# ...              ...   ...   ...    ...      ...     ...       ...   ...
# 9_CGTCTGCTCCAG     0     0     0      1      339       0         0     3
# 9_TAACGGTCTATT     0     6     0      2      464       0         2     6
# 9_TCAATGTGGGGT     0    14     0      5      353       0         0     4
# 9_CAGCACTGCTCT     0     0     0      2      369       0         3     1
# 9_TAGATCTAGCTA     1     3     0      1      342       0         0     1
#
#                 RPL13A  VRK2  ...  LINC02267  AC109466.1  LINC01938  \
# 8_CGCAATGCATCG      36     1  ...          0           0          0
# 8_GCTCTATAAGTA      27     1  ...          0           0          0
# 8_GCGCGGACCAGG      46     0  ...          0           0          0
# 8_CGGTGGCCCGTG      19     0  ...          0           0          0
# 8_TTCCGCATCTTA      17     0  ...          0           0          0
# ...                ...   ...  ...        ...         ...        ...
# 9_CGTCTGCTCCAG       2     0  ...          0           0          0
# 9_TAACGGTCTATT       0     0  ...          0           0          0
# 9_TCAATGTGGGGT       3     0  ...          0           0          0
# 9_CAGCACTGCTCT       1     0  ...          0           0          0
# 9_TAGATCTAGCTA       0     1  ...          0           0          0
#
#                 AC008708.2  AL360175.1  AL121718.1  C7orf71  YWHAEP1  \
# 8_CGCAATGCATCG           0           0           0        0        0
# 8_GCTCTATAAGTA           0           0           0        0        0
# 8_GCGCGGACCAGG           0           0           0        0        0
# 8_CGGTGGCCCGTG           0           0           0        0        0
# 8_TTCCGCATCTTA           0           0           0        0        0
# ...                    ...         ...         ...      ...      ...
# 9_CGTCTGCTCCAG           0           0           0        0        0
# 9_TAACGGTCTATT           0           0           0        0        0
# 9_TCAATGTGGGGT           0           0           0        0        0
# 9_CAGCACTGCTCT           0           0           0        0        0
# 9_TAGATCTAGCTA           0           0           0        0        0
#
#                 LINC01287  LUZP4
# 8_CGCAATGCATCG          0      0
# 8_GCTCTATAAGTA          0      0
# 8_GCGCGGACCAGG          0      0
# 8_CGGTGGCCCGTG          0      0
# 8_TTCCGCATCTTA          0      0
# ...                   ...    ...
# 9_CGTCTGCTCCAG          0      0
# 9_TAACGGTCTATT          0      0
# 9_TCAATGTGGGGT          0      0
# 9_CAGCACTGCTCT          0      0
# 9_TAGATCTAGCTA          0      0
#
# [2454 rows x 29527 columns]
